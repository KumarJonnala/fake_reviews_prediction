# %%
import requests

# %%
model = "gemma3:4b" # specify the model name

# %%
# Function to query the local LLM server

def query_llm(prompt: str, model: str = model) -> str: # arguments promt and model
    # Send a request to the local LLM server, stream set to Falsefor single responce
    response = requests.post(
        "http://localhost:11434/api/generate",  
        json={"model": model, "prompt": prompt, "stream": False}
    )
    return response.json()["response"]

# %%
prompt = """Classify the sentiment of below statement into Original reviews, Computer-generated.
'Love this!  Well made, sturdy, and very comfortable.  I love it!Very pretty' """

# %%
print(query_llm(prompt))
# Out:
# **Classification: Original Reviews**
#
# **Reasoning:**
#
# *   **Expressive Language:** The review uses enthusiastic language like "Love this!", "I love it!", and descriptive terms like "well made," "sturdy," and "very pretty." These are hallmarks of a genuine, human-written review.
# *   **Specific Details:** The reviewer provides specific qualities they appreciate – construction quality, comfort, and aesthetics.
# *   **Natural Tone:** The phrasing and sentence structure are natural and conversational, reflecting how someone would likely express their opinion about a product.
#
# **Computer-generated reviews** tend to be bland, generic, and lack specific details or emotional expression.
